# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
t = np.arange(0.01, 5.0, 0.01)
s1 = np.sin(2 * np.pi * t)
s2 = np.cos(2 * np.pi * t)

plt.plot(t, s1, color='purple')
plt.plot(t, s2, color='red')
# plt.setp(ax1.get_xticklabels(), fontsize=6)

# %%
my_first_dict = {"A": 1, "B": 2}
my_second_dict = {"C": 3, "D": 4}

# %%
my_first_dict
# Out:
# {'A': 1, 'B': 2}

# %%
my_second_dict
# Out:
# {'C': 3, 'D': 4}

# %%
my_merged_dict = {**my_first_dict, **my_second_dict}
my_merged_dict
# Out:
# {'A': 1, 'B': 2, 'C': 3, 'D': 4}

# %%
a = [1,2,3,123,123,]
b = ['hello']
c = [*a, *b]
print(c)
# Out:
# [1, 2, 3, 123, 123, 'hello']

# %%
l = [1,2,3,4]
a,*b,c = l

# %%
b
# Out:
# [2, 3]

# %%
my_list = [1,{'a':5, 'd':10}, 6]

a, *b, c = my_list

print(a)
print(b)
print(c)
# Out:
# 1
# [{'a': 5, 'd': 10}]
# 6
